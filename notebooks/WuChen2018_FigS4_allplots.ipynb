# %% [markdown]
# ### Original Paper
# https://doi.org/10.1016/j.bbrc.2018.04.095

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
metadata = pd.read_csv('../data/wu_chen_2018/metadata_cleaned_chen_2018.txt', sep='\t', index_col=0)
metadata
# Out:
#                   site  time group subgroup  numberID  number  organ  \
# #SampleID
# caecumZT2.LD1   caecum   ZT2    LD    LDZT2         1       1  cecum
# caecumZT2.LD2   caecum   ZT2    LD    LDZT2         2       2  cecum
# caecumZT2.LD3   caecum   ZT2    LD    LDZT2         3       3  cecum
# caecumZT2.LD4   caecum   ZT2    LD    LDZT2         4       4  cecum
# caecumZT2.LD5   caecum   ZT2    LD    LDZT2         5       5  cecum
# ...                ...   ...   ...      ...       ...     ...    ...
# colonEZT22.DD1  colonE  ZT22    DD   DDZT22         1     896  colon
# colonEZT22.DD2  colonE  ZT22    DD   DDZT22         2     897  colon
# colonEZT22.DD3  colonE  ZT22    DD   DDZT22         3     898  colon
# colonEZT22.DD4  colonE  ZT22    DD   DDZT22         4     899  colon
# colonEZT22.DD5  colonE  ZT22    DD   DDZT22         5     900  colon
#
#                      niche feeding_pattern   combined combined2  \
# #SampleID
# ...

# %% [markdown]
# ## PCoA

# %%
pcoa = pd.read_csv('../data/wu_chen_2018/SI_1085_wUF_pcoa.txt', sep='\t', usecols=range(4), index_col=0)
pcoa.head()
# Out:
#                 Axis1_25.2  Axis2_16_2  Axis3_9_67
# dsiEZT6.RF4       0.298905    0.074867   -0.222436
# colonLZT10.RF3   -1.137914    1.149378    0.441862
# colonLZT2.RF1    -0.673842    0.167621    0.015971
# psiEZT2.DD2       0.185480   -0.041310   -0.027691
# colonLZT6.DD2    -0.519119   -0.204224    0.026715

# %%
named_pcoa = pd.merge(pcoa, metadata[metadata['feeding_pattern'] == 'ad libitum'], left_index=True, right_index=True)
named_pcoa.head()
# Out:
#                 Axis1_25.2  Axis2_16_2  Axis3_9_67    site  time group  \
# colonEZT10.LD2   -0.241708   -0.075581    0.044337  colonE  ZT10    LD
# colonEZT10.LD3   -0.168728   -0.081582   -0.202647  colonE  ZT10    LD
# colonEZT10.LD4    0.007264   -0.076396   -0.240104  colonE  ZT10    LD
# colonEZT10.LD5   -0.116400   -0.034733   -0.207749  colonE  ZT10    LD
# colonEZT14.DD1   -0.294365    1.260900   -0.351149  colonE  ZT14    DD
#
#                subgroup  numberID  number  organ       niche feeding_pattern  \
# colonEZT10.LD2   LDZT10         2     842  colon  epithelium      ad libitum
# colonEZT10.LD3   LDZT10         3     843  colon  epithelium      ad libitum
# colonEZT10.LD4   LDZT10         4     844  colon  epithelium      ad libitum
# colonEZT10.LD5   LDZT10         5     845  colon  epithelium      ad libitum
# colonEZT14.DD1   DDZT14         1     866  colon  epithelium      ad libitum
#
#                  combined combined2           combined3  \
# ...

# %%
named_pcoa.niche.unique()
# Out:
# array(['epithelium', 'lumen', 'mucosal'], dtype=object)

# %%
niche_pcoa = named_pcoa[named_pcoa['niche'] != 'epithelium']
lumen_pcoa = named_pcoa[named_pcoa['niche'] == 'lumen']
mucosal_pcoa = named_pcoa[named_pcoa['niche'] == 'mucosal']

# %%
ax = sns.stripplot(x="time", y="Axis1_25.2", hue='organ', dodge=True,
                   edgecolor='k', linewidth=1, size=9,
                   data=lumen_pcoa,
                   #data=lumen_pcoa[lumen_pcoa["group"] == 'LD'],
                     order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Axis1 25.2%')
plt.title('Colon wUF PCoA Axis1')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
#plt.savefig('../figures/chen_colon_wUF_pcoa_Axis1.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.stripplot(x="time", y="Axis1_25.2", hue='niche', 
                   palette=['lightblue', 'darkgreen'], edgecolor='k', linewidth=1, size=9,
                   data=niche_pcoa[niche_pcoa['organ'] == 'colon'], order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Axis1 25.2%')
plt.title('Colon wUF PCoA Axis1')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_colon_wUF_pcoa_Axis1.svg', dpi=300, bbox_inches="tight")

# %%
niche_pcoa[niche_pcoa['organ'] == 'colon']
# Out:
#                 Axis1_25.2  Axis2_16_2  Axis3_9_67    site  time group  \
# colonLZT10.LD2   -0.574769   -0.286346    0.166081  colonL  ZT10    LD
# colonLZT10.LD3   -0.565831   -0.274125    0.163982  colonL  ZT10    LD
# colonLZT10.LD4   -0.484758   -0.201233    0.081329  colonL  ZT10    LD
# colonLZT10.LD5   -0.521292   -0.191801    0.049169  colonL  ZT10    LD
# colonLZT14.DD1   -0.089104    0.204668   -0.499029  colonL  ZT14    DD
# ...                    ...         ...         ...     ...   ...   ...
# colonMZT6.DD3    -0.580998   -0.266660    0.133762  colonM   ZT6    DD
# colonMZT6.LD2    -0.502481   -0.181229   -0.028277  colonM   ZT6    LD
# colonMZT6.LD3    -0.501921   -0.182903    0.056019  colonM   ZT6    LD
# colonMZT6.LD4    -0.393890   -0.117610   -0.128506  colonM   ZT6    LD
# colonMZT6.LD5    -0.532286   -0.230028    0.093787  colonM   ZT6    LD
#
#                subgroup  numberID  number  organ    niche feeding_pattern  \
# ...

# %%
niche_pcoa[niche_pcoa['organ'] == 'colon'].time.value_counts()
# Out:
# ZT2     17
# ZT22    16
# ZT6     16
# ZT18    11
# ZT14    10
# ZT10     6
# Name: time, dtype: int64

# %%
ax = sns.stripplot(x="time", y="Axis1_25.2", hue='group', 
                   palette=['darkgreen', 'lightblue'], edgecolor='k', linewidth=1, size=9,
                   data=mucosal_pcoa, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Axis1 25.2%')
plt.title('Mucosal wUF PCoA Axis1')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_mucosal_wUF_pcoa_Axis1.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.stripplot(x="time", y="Axis1_25.2", hue='group', 
                   palette=['lightblue', 'darkgreen'], edgecolor='k', linewidth=1, size=9,
                   data=lumen_pcoa, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Axis1 25.2%')
plt.title('Lumen wUF PCoA Axis1')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_lumen_wUF_pcoa_Axis1.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.scatterplot(x="Axis2_16_2", y="Axis1_25.2", hue='group', palette=['lightblue', 'darkgreen'], 
                   edgecolor='k', linewidth=1,
                   data=niche_pcoa)
plt.title('Chen SI wUF PCoA Axis1&2')
plt.ylabel('Axis1 25.2%')
plt.xlabel('Axis2 16.2%')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_SI_wUF_pcoa_groups.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.scatterplot(x="Axis2_16_2", y="Axis1_25.2", hue='niche', palette=['lightblue', 'darkgreen'], 
                   edgecolor='k', linewidth=1,
                   data=niche_pcoa[niche_pcoa['organ'] == 'jejunum'])
plt.title('Jejunum wUF PCoA Axis1&2')
plt.ylabel('Axis1 25.2%')
plt.xlabel('Axis2 16.2%')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_jejunum_wUF_pcoa_groups.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.scatterplot(x="Axis2_16_2", y="Axis1_25.2", hue='group', 
                     palette=['lightblue', 'darkgreen'], 
                   edgecolor='k', linewidth=1,
                   data=lumen_pcoa)
plt.title('Chen Lumen wUF PCoA Axis1&2')
plt.ylabel('Axis1 25.2%')
plt.xlabel('Axis2 16.2%')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_lumen_wUF_pcoa_groups.svg', dpi=300, bbox_inches="tight")

# %%
ax = sns.scatterplot(x="Axis2_16_2", y="Axis1_25.2", hue='group', 
                     palette=['darkgreen', 'lightblue'], 
                   edgecolor='k', linewidth=1,
                   data=mucosal_pcoa)
plt.title('Chen Mucosal wUF PCoA Axis1&2')
plt.ylabel('Axis1 25.2%')
plt.xlabel('Axis2 16.2%')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_mucosal_wUF_pcoa_groups.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# # Boxplots

# %% [markdown]
# ### All SI Together

# %%
SI_wUF_dm = pd.read_csv('../data/wu_chen_2018/SI_wUF_DM_1085.tsv', sep='\t', index_col=0)
SI_wUF_dm.head()
# Out:
#                 dsiEZT6.RF4  colonLZT10.RF3  colonLZT2.RF1  psiEZT2.DD2  \
# dsiEZT6.RF4        0.000000        2.033037       1.215335     0.863704
# colonLZT10.RF3     2.033037        0.000000       1.343089     1.904898
# colonLZT2.RF1      1.215335        1.343089       0.000000     1.112438
# psiEZT2.DD2        0.863704        1.904898       1.112438     0.000000
# colonLZT6.DD2      1.121946        1.539341       0.447006     0.904897
#
#                 colonLZT6.DD2  dsiMZT18.DD4  colonLZT14.RF2  dsiLZT22.LD4  \
# dsiEZT6.RF4          1.121946      0.863562        1.077196      0.943738
# colonLZT10.RF3       1.539341      1.725215        1.536466      1.728897
# colonLZT2.RF1        0.447006      0.886137        0.485135      0.825230
# psiEZT2.DD2          0.904897      0.639447        0.886390      0.834600
# colonLZT6.DD2        0.000000      0.582347        0.191136      0.590968
#
#                 psiEZT2.RF4  colonLZT2.LD2  ...  dsiMZT14.DD4  psiLZT14.DD1  \
# ...

# %%
named_SI_wUF_dm = pd.merge(metadata[['combined4']], SI_wUF_dm, left_index=True, right_index=True)
named_SI_wUF_dm.head()
# Out:
#                       combined4  dsiEZT6.RF4  colonLZT10.RF3  colonLZT2.RF1  \
# dsiLZT2.LD1  lumen_ileum_LD_ZT2     0.752677        1.907843       1.108910
# dsiLZT2.LD2  lumen_ileum_LD_ZT2     0.739695        1.876845       1.080552
# dsiLZT2.LD3  lumen_ileum_LD_ZT2     0.845811        1.899468       1.088504
# dsiLZT2.LD4  lumen_ileum_LD_ZT2     0.730867        1.903837       1.109094
# dsiLZT2.LD5  lumen_ileum_LD_ZT2     0.916643        2.071313       1.276226
#
#              psiEZT2.DD2  colonLZT6.DD2  dsiMZT18.DD4  colonLZT14.RF2  \
# dsiLZT2.LD1     0.645052       0.891671      0.589639        0.870061
# dsiLZT2.LD2     0.568364       0.864561      0.530183        0.842481
# dsiLZT2.LD3     0.715929       0.869353      0.576904        0.850573
# dsiLZT2.LD4     0.638508       0.910986      0.591056        0.892958
# dsiLZT2.LD5     0.820268       1.051366      0.783709        1.030349
#
#              dsiLZT22.LD4  psiEZT2.RF4  ...  dsiMZT14.DD4  psiLZT14.DD1  \
# ...

# %%
named2_SI_wUF_dm = named_SI_wUF_dm.set_index('combined4')

# %%
Named_SI_wUF_dm = named_SI_wUF_dm[['combined4']].copy()
Named_SI_wUF_dm.head()
# Out:
#                       combined4
# dsiLZT2.LD1  lumen_ileum_LD_ZT2
# dsiLZT2.LD2  lumen_ileum_LD_ZT2
# dsiLZT2.LD3  lumen_ileum_LD_ZT2
# dsiLZT2.LD4  lumen_ileum_LD_ZT2
# dsiLZT2.LD5  lumen_ileum_LD_ZT2

# %%
named3_SI_wUF_dm = pd.merge(named2_SI_wUF_dm.T, Named_SI_wUF_dm, left_index=True, right_index=True)
named4_SI_wUF_dm = named3_SI_wUF_dm.set_index('combined4')
named4_SI_wUF_dm
# Out:
#                             lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# epithelium_ileum_RF_ZT6               0.752677            0.739695
# lumen_colon_RF_ZT10                   1.907843            1.876845
# lumen_colon_RF_ZT2                    1.108910            1.080552
# epithelium_jejunum_DD_ZT2             0.645052            0.568364
# lumen_colon_DD_ZT6                    0.891671            0.864561
# ...                                        ...                 ...
# lumen_ileum_RF_ZT22                   0.465615            0.413695
# epithelium_jejunum_DD_ZT14            0.492424            0.423429
# lumen_jejunum_RF_ZT2                  0.417937            0.352267
# lumen_colon_DD_ZT14                   0.755048            0.718888
# mucosal_jejunum_RF_ZT2                0.471982            0.379380
#
#                             lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# epithelium_ileum_RF_ZT6               0.845811            0.730867
# ...

# %%
LD = named4_SI_wUF_dm.filter(regex='LD')
LD2 = LD.T.filter(regex='LD')
LD2.head()
# Out:
# combined4           lumen_ileum_LD_ZT22  lumen_colon_LD_ZT2  \
# lumen_ileum_LD_ZT2             0.626761            0.857114
# lumen_ileum_LD_ZT2             0.610720            0.825087
# lumen_ileum_LD_ZT2             0.657522            0.837791
# lumen_ileum_LD_ZT2             0.606691            0.877863
# lumen_ileum_LD_ZT2             0.751758            1.011592
#
# combined4           epithelium_jejunum_LD_ZT6  mucosal_jejunum_LD_ZT10  \
# lumen_ileum_LD_ZT2                   0.682729                 0.574080
# lumen_ileum_LD_ZT2                   0.607338                 0.519054
# lumen_ileum_LD_ZT2                   0.685930                 0.636460
# lumen_ileum_LD_ZT2                   0.652952                 0.535672
# lumen_ileum_LD_ZT2                   0.863740                 0.744232
#
# combined4           lumen_jejunum_LD_ZT22  epithelium_colon_LD_ZT14  \
# lumen_ileum_LD_ZT2               0.301967                  0.757564
# ...

# %%
LD_lum_dm = LD2.filter(regex='lumen')
LD_lum_muc_dm = LD_lum_dm.T.filter(regex='mucosal')
LD_lum_muc_dm.shape
# Out:
# (69, 67)

# %%
LD_lum_muc_dm2 = LD_lum_muc_dm.copy()
LD_lum_muc_dm3 = LD_lum_muc_dm2.stack().reset_index()
LD_lum_muc_dm3.columns = ['Lumen','Mucosal','Value']
LD_lum_muc_dm3
# Out:
#                     Lumen                Mucosal     Value
# 0     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  1.022105
# 1     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.627475
# 2     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.696132
# 3     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.646791
# 4     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.700223
# ...                   ...                    ...       ...
# 4618  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.653535
# 4619  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.643660
# 4620  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.704083
# 4621  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.743786
# 4622  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  1.090299
#
# [4623 rows x 3 columns]

# %%
LD_lum_muc_dm3['timepoints'] = LD_lum_muc_dm3['Lumen'].str.split('_').str[-1] + "_" + LD_lum_muc_dm3['Mucosal'].str.split('_').str[-1]
LD_lum_muc_dm3.timepoints.unique()
# Out:
# array(['ZT22_ZT2', 'ZT22_ZT6', 'ZT22_ZT10', 'ZT22_ZT14', 'ZT22_ZT18',
#        'ZT22_ZT22', 'ZT2_ZT2', 'ZT2_ZT6', 'ZT2_ZT10', 'ZT2_ZT14',
#        'ZT2_ZT18', 'ZT2_ZT22', 'ZT6_ZT2', 'ZT6_ZT6', 'ZT6_ZT10',
#        'ZT6_ZT14', 'ZT6_ZT18', 'ZT6_ZT22', 'ZT18_ZT2', 'ZT18_ZT6',
#        'ZT18_ZT10', 'ZT18_ZT14', 'ZT18_ZT18', 'ZT18_ZT22', 'ZT10_ZT2',
#        'ZT10_ZT6', 'ZT10_ZT10', 'ZT10_ZT14', 'ZT10_ZT18', 'ZT10_ZT22',
#        'ZT14_ZT2', 'ZT14_ZT6', 'ZT14_ZT10', 'ZT14_ZT14', 'ZT14_ZT18',
#        'ZT14_ZT22'], dtype=object)

# %%
zt_tps = ['ZT2_ZT2', 'ZT6_ZT6', 'ZT10_ZT10', 'ZT14_ZT14', 'ZT18_ZT18', 'ZT22_ZT22']

# %%
LD_lum_muc_dm4 = LD_lum_muc_dm3.loc[LD_lum_muc_dm3['timepoints'].isin(zt_tps)]
LD_lum_muc_dm4
# Out:
#                     Lumen                  Mucosal     Value timepoints
# 20    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.470506  ZT22_ZT22
# 21    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.594470  ZT22_ZT22
# 22    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.583236  ZT22_ZT22
# 43    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.243755  ZT22_ZT22
# 44    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.755517  ZT22_ZT22
# ...                   ...                      ...       ...        ...
# 4567  lumen_ileum_LD_ZT10    mucosal_ileum_LD_ZT10  0.291631  ZT10_ZT10
# 4587  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480301  ZT10_ZT10
# 4588  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480678  ZT10_ZT10
# 4589  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.528108  ZT10_ZT10
# 4611  lumen_ileum_LD_ZT10    mucosal_colon_LD_ZT10  0.647024  ZT10_ZT10
#
# [784 rows x 4 columns]

# %%
LD_lum_muc_dm5 = LD_lum_muc_dm4.copy()
LD_lum_muc_dm5['ZT'] = LD_lum_muc_dm5['timepoints'].str.split('_').str[-1]
LD_lum_muc_dm5
# Out:
#                     Lumen                  Mucosal     Value timepoints    ZT
# 20    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.470506  ZT22_ZT22  ZT22
# 21    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.594470  ZT22_ZT22  ZT22
# 22    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.583236  ZT22_ZT22  ZT22
# 43    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.243755  ZT22_ZT22  ZT22
# 44    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.755517  ZT22_ZT22  ZT22
# ...                   ...                      ...       ...        ...   ...
# 4567  lumen_ileum_LD_ZT10    mucosal_ileum_LD_ZT10  0.291631  ZT10_ZT10  ZT10
# 4587  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480301  ZT10_ZT10  ZT10
# 4588  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480678  ZT10_ZT10  ZT10
# 4589  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.528108  ZT10_ZT10  ZT10
# 4611  lumen_ileum_LD_ZT10    mucosal_colon_LD_ZT10  0.647024  ZT10_ZT10  ZT10
#
# [784 rows x 5 columns]

# %%
LD_lum_muc_dm5.Value.mean()
# Out:
# 0.6123719478224652

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LD_lum_muc_dm5, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LD_lum_muc_dm5, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.ylabel('All SI LD wUF BCD-Lum v Muc')
ax.axhline(0.6123719478224652, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_allSI_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %%
LD_all = named4_SI_wUF_dm.filter(regex='LD')
LD_all2 = LD_all.T.filter(regex='DD')
LD_all2.head()
# Out:
# combined4           epithelium_jejunum_DD_ZT2  lumen_colon_DD_ZT6  \
# lumen_ileum_LD_ZT2                   0.645052            0.891671
# lumen_ileum_LD_ZT2                   0.568364            0.864561
# lumen_ileum_LD_ZT2                   0.715929            0.869353
# lumen_ileum_LD_ZT2                   0.638508            0.910986
# lumen_ileum_LD_ZT2                   0.820268            1.051366
#
# combined4           mucosal_ileum_DD_ZT18  lumen_jejunum_DD_ZT18  \
# lumen_ileum_LD_ZT2               0.589639               0.710872
# lumen_ileum_LD_ZT2               0.530183               0.636808
# lumen_ileum_LD_ZT2               0.576904               0.687283
# lumen_ileum_LD_ZT2               0.591056               0.706053
# lumen_ileum_LD_ZT2               0.783709               0.901329
#
# combined4           mucosal_colon_DD_ZT6  epithelium_jejunum_DD_ZT18  \
# lumen_ileum_LD_ZT2              0.807769                    0.620875
# ...

# %%
LD_all3 = LD_all2.filter(regex='lumen')
LD_all_lum = LD_all3.T.filter(regex='lumen')
LD_all_lum.head()
# Out:
#                        lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# lumen_colon_DD_ZT6               0.891671            0.864561
# lumen_jejunum_DD_ZT18            0.710872            0.636808
# lumen_colon_DD_ZT14              1.051054            1.006903
# lumen_ileum_DD_ZT18              0.701739            0.666213
# lumen_colon_DD_ZT18              0.822255            0.792185
#
#                        lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# lumen_colon_DD_ZT6               0.869353            0.910986
# lumen_jejunum_DD_ZT18            0.687283            0.706053
# lumen_colon_DD_ZT14              1.024700            1.046716
# lumen_ileum_DD_ZT18              0.717205            0.730206
# lumen_colon_DD_ZT18              0.798883            0.841171
#
#                        lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT6  \
# combined4
# lumen_colon_DD_ZT6               1.051366            0.512160
# ...

# %%
LD_all_lum2 = LD_all_lum.copy()
LD_all_lum3 = LD_all_lum2.stack().reset_index()
LD_all_lum3.columns = ['LD','DD','Value']
LD_all_lum3.head()
# Out:
#                    LD                  DD     Value
# 0  lumen_colon_DD_ZT6  lumen_ileum_LD_ZT2  0.891671
# 1  lumen_colon_DD_ZT6  lumen_ileum_LD_ZT2  0.864561
# 2  lumen_colon_DD_ZT6  lumen_ileum_LD_ZT2  0.869353
# 3  lumen_colon_DD_ZT6  lumen_ileum_LD_ZT2  0.910986
# 4  lumen_colon_DD_ZT6  lumen_ileum_LD_ZT2  1.051366

# %%
LD_all_lum3['timepoints'] = LD_all_lum3['LD'].str.split('_').str[-1] + "_" + LD_all_lum3['DD'].str.split('_').str[-1]
LD_all_lum3.timepoints.unique()
# Out:
# array(['ZT6_ZT2', 'ZT6_ZT6', 'ZT6_ZT10', 'ZT6_ZT14', 'ZT6_ZT18',
#        'ZT6_ZT22', 'ZT18_ZT2', 'ZT18_ZT6', 'ZT18_ZT10', 'ZT18_ZT14',
#        'ZT18_ZT18', 'ZT18_ZT22', 'ZT14_ZT2', 'ZT14_ZT6', 'ZT14_ZT10',
#        'ZT14_ZT14', 'ZT14_ZT18', 'ZT14_ZT22', 'ZT2_ZT2', 'ZT2_ZT6',
#        'ZT2_ZT10', 'ZT2_ZT14', 'ZT2_ZT18', 'ZT2_ZT22', 'ZT10_ZT2',
#        'ZT10_ZT6', 'ZT10_ZT10', 'ZT10_ZT14', 'ZT10_ZT18', 'ZT10_ZT22',
#        'ZT22_ZT2', 'ZT22_ZT6', 'ZT22_ZT10', 'ZT22_ZT14', 'ZT22_ZT18',
#        'ZT22_ZT22'], dtype=object)

# %%
LD_all_lum3['organs'] = LD_all_lum3['LD'].str.split('_').str[1] + "_" + LD_all_lum3['DD'].str.split('_').str[1]
LD_all_lum3.organs.unique()
# Out:
# array(['colon_ileum', 'colon_jejunum', 'colon_colon', 'jejunum_ileum',
#        'jejunum_jejunum', 'jejunum_colon', 'ileum_ileum', 'ileum_jejunum',
#        'ileum_colon'], dtype=object)

# %%
LD_all_lum4 = LD_all_lum3.loc[LD_all_lum3['timepoints'].isin(zt_tps)]
LD_all_lum4
# Out:
#                        LD                     DD     Value timepoints  \
# 5      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.512160    ZT6_ZT6
# 6      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.657141    ZT6_ZT6
# 7      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.857793    ZT6_ZT6
# 8      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.902342    ZT6_ZT6
# 9      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.758518    ZT6_ZT6
# ...                   ...                    ...       ...        ...
# 4570  lumen_colon_DD_ZT14    lumen_ileum_LD_ZT14  0.618643  ZT14_ZT14
# 4592  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.805419  ZT14_ZT14
# 4593  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.858640  ZT14_ZT14
# 4594  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.837855  ZT14_ZT14
# 4618  lumen_colon_DD_ZT14    lumen_colon_LD_ZT14  0.426379  ZT14_ZT14
#
#             niche         organs
# 5     lumen_lumen    colon_ileum
# 6     lumen_lumen    colon_ileum
# ...

# %%
LD_all_lum5 = LD_all_lum4.copy()
LD_all_lum5['ZT'] = LD_all_lum5['timepoints'].str.split('_').str[-1]
LD_all_lum5
# Out:
#                        LD                     DD     Value timepoints  \
# 5      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.512160    ZT6_ZT6
# 6      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.657141    ZT6_ZT6
# 7      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.857793    ZT6_ZT6
# 8      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.902342    ZT6_ZT6
# 9      lumen_colon_DD_ZT6     lumen_ileum_LD_ZT6  0.758518    ZT6_ZT6
# ...                   ...                    ...       ...        ...
# 4570  lumen_colon_DD_ZT14    lumen_ileum_LD_ZT14  0.618643  ZT14_ZT14
# 4592  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.805419  ZT14_ZT14
# 4593  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.858640  ZT14_ZT14
# 4594  lumen_colon_DD_ZT14  lumen_jejunum_LD_ZT14  0.837855  ZT14_ZT14
# 4618  lumen_colon_DD_ZT14    lumen_colon_LD_ZT14  0.426379  ZT14_ZT14
#
#             niche         organs    ZT
# 5     lumen_lumen    colon_ileum   ZT6
# 6     lumen_lumen    colon_ileum   ZT6
# ...

# %%
LDvDD_lum_ileum = LD_all_lum5[LD_all_lum5['organs'] == 'ileum_ileum'].copy()
LDvDD_lum_jejunum = LD_all_lum5[LD_all_lum5['organs'] == 'jejunum_jejunum'].copy()
LDvDD_lum_colon = LD_all_lum5[LD_all_lum5['organs'] == 'colon_colon'].copy()

# %%
LDvDD_lum_ileum.shape
# Out:
# (109, 7)

# %%
from statannot import add_stat_annotation

# %%
LDvDD_lum_ileum.Value.median()
# Out:
# 0.5343440198723557

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LDvDD_lum_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LDvDD_lum_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum Luminal Contents wUF', fontsize=14)
plt.ylabel('BCD-LDvDD')
ax.axhline(0.5343440198723557, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_ileum_lum_LDvDD_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %%
boxpairs = [('ZT22', 'ZT6'), ('ZT2', 'ZT22'), ('ZT22', 'ZT14'), ('ZT22', 'ZT18'), ('ZT10', 'ZT22')] 

ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LDvDD_lum_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LDvDD_lum_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum Luminal Contents wUF', fontsize=14)
plt.ylabel('BCD-LDvDD')
ax.axhline(0.5343440198723557, color='k', ls='--')

ax, test_results = add_stat_annotation(ax, data=LDvDD_lum_ileum, x="ZT", y="Value", 
                                       order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'], 
                                       box_pairs = boxpairs,
                                       test='Mann-Whitney', text_format='star', loc='outside', verbose=2)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_ileum_lum_LDvDD_wUF_boxplot2.svg', dpi=300, bbox_inches="tight")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ZT18 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.861e-07 U_stat=0.000e+00
# ZT14 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.158e-05 U_stat=0.000e+00
# ZT10 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.360e-05 U_stat=0.000e+00
# ZT6 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.909e-06 U_stat=0.000e+00
# ZT2 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.861e-07 U_stat=0.000e+00

# %%
LDvDD_lum_jejunum.Value.mean()
# Out:
# 0.4940588498583712

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LDvDD_lum_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LDvDD_lum_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum Luminal Contents wUF', fontsize=14)
plt.ylabel('BCD-LDvDD')
ax.axhline(0.4940588498583712, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_jejunum_lum_LDvDD_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %%
boxpairs = [('ZT10', 'ZT6'), ('ZT2', 'ZT10'), ('ZT10', 'ZT14'), ('ZT10', 'ZT18'), ('ZT10', 'ZT22')] 

ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LDvDD_lum_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LDvDD_lum_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum Luminal Contents wUF', fontsize=14)
plt.ylabel('BCD-LDvDD')
ax.axhline(0.5343440198723557, color='k', ls='--')

ax, test_results = add_stat_annotation(ax, data=LDvDD_lum_jejunum, x="ZT", y="Value", 
                                       order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'], 
                                       box_pairs = boxpairs,
                                       test='Mann-Whitney', text_format='star', loc='outside', verbose=2)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_jejunum_lum_LDvDD_wUF_boxplot2.svg', dpi=300, bbox_inches="tight")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ZT6 v.s. ZT10: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.745e-01 U_stat=8.800e+01
# ZT10 v.s. ZT14: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.685e-01 U_stat=2.600e+01
# ZT2 v.s. ZT10: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.745e-01 U_stat=8.800e+01
# ZT10 v.s. ZT18: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=5.300e+01
# ZT10 v.s. ZT22: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.700e+01

# %%
LDvDD_lum_colon.Value.mean()
# Out:
# 0.5694627506274029

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LDvDD_lum_colon, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LDvDD_lum_colon, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum Luminal Contents wUF', fontsize=14)
plt.ylabel('BCD-LDvDD')
ax.axhline(0.5694627506274029, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_colon_lum_LDvDD_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### Separate by Organ

# %%
named_SI_wUF_dm = pd.merge(metadata[['combined4']], SI_wUF_dm, left_index=True, right_index=True)
named_SI_wUF_dm.head()
# Out:
#                       combined4  dsiEZT6.RF4  colonLZT10.RF3  colonLZT2.RF1  \
# dsiLZT2.LD1  lumen_ileum_LD_ZT2     0.752677        1.907843       1.108910
# dsiLZT2.LD2  lumen_ileum_LD_ZT2     0.739695        1.876845       1.080552
# dsiLZT2.LD3  lumen_ileum_LD_ZT2     0.845811        1.899468       1.088504
# dsiLZT2.LD4  lumen_ileum_LD_ZT2     0.730867        1.903837       1.109094
# dsiLZT2.LD5  lumen_ileum_LD_ZT2     0.916643        2.071313       1.276226
#
#              psiEZT2.DD2  colonLZT6.DD2  dsiMZT18.DD4  colonLZT14.RF2  \
# dsiLZT2.LD1     0.645052       0.891671      0.589639        0.870061
# dsiLZT2.LD2     0.568364       0.864561      0.530183        0.842481
# dsiLZT2.LD3     0.715929       0.869353      0.576904        0.850573
# dsiLZT2.LD4     0.638508       0.910986      0.591056        0.892958
# dsiLZT2.LD5     0.820268       1.051366      0.783709        1.030349
#
#              dsiLZT22.LD4  psiEZT2.RF4  ...  dsiMZT14.DD4  psiLZT14.DD1  \
# ...

# %%
named2_SI_wUF_dm = named_SI_wUF_dm.set_index('combined4')

# %%
Named_SI_wUF_dm = named_SI_wUF_dm[['combined4']].copy()
Named_SI_wUF_dm.head()
# Out:
#                       combined4
# dsiLZT2.LD1  lumen_ileum_LD_ZT2
# dsiLZT2.LD2  lumen_ileum_LD_ZT2
# dsiLZT2.LD3  lumen_ileum_LD_ZT2
# dsiLZT2.LD4  lumen_ileum_LD_ZT2
# dsiLZT2.LD5  lumen_ileum_LD_ZT2

# %%
named3_SI_wUF_dm = pd.merge(named2_SI_wUF_dm.T, Named_SI_wUF_dm, left_index=True, right_index=True)
named4_SI_wUF_dm = named3_SI_wUF_dm.set_index('combined4')
named4_SI_wUF_dm
# Out:
#                             lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# epithelium_ileum_RF_ZT6               0.752677            0.739695
# lumen_colon_RF_ZT10                   1.907843            1.876845
# lumen_colon_RF_ZT2                    1.108910            1.080552
# epithelium_jejunum_DD_ZT2             0.645052            0.568364
# lumen_colon_DD_ZT6                    0.891671            0.864561
# ...                                        ...                 ...
# lumen_ileum_RF_ZT22                   0.465615            0.413695
# epithelium_jejunum_DD_ZT14            0.492424            0.423429
# lumen_jejunum_RF_ZT2                  0.417937            0.352267
# lumen_colon_DD_ZT14                   0.755048            0.718888
# mucosal_jejunum_RF_ZT2                0.471982            0.379380
#
#                             lumen_ileum_LD_ZT2  lumen_ileum_LD_ZT2  \
# combined4
# epithelium_ileum_RF_ZT6               0.845811            0.730867
# ...

# %%
LD = named4_SI_wUF_dm.filter(regex='LD')
LD2 = LD.T.filter(regex='LD')
LD2.head()
# Out:
# combined4           lumen_ileum_LD_ZT22  lumen_colon_LD_ZT2  \
# lumen_ileum_LD_ZT2             0.626761            0.857114
# lumen_ileum_LD_ZT2             0.610720            0.825087
# lumen_ileum_LD_ZT2             0.657522            0.837791
# lumen_ileum_LD_ZT2             0.606691            0.877863
# lumen_ileum_LD_ZT2             0.751758            1.011592
#
# combined4           epithelium_jejunum_LD_ZT6  mucosal_jejunum_LD_ZT10  \
# lumen_ileum_LD_ZT2                   0.682729                 0.574080
# lumen_ileum_LD_ZT2                   0.607338                 0.519054
# lumen_ileum_LD_ZT2                   0.685930                 0.636460
# lumen_ileum_LD_ZT2                   0.652952                 0.535672
# lumen_ileum_LD_ZT2                   0.863740                 0.744232
#
# combined4           lumen_jejunum_LD_ZT22  epithelium_colon_LD_ZT14  \
# lumen_ileum_LD_ZT2               0.301967                  0.757564
# ...

# %%
LD_lum_dm = LD2.filter(regex='lumen')
LD_lum_muc_dm = LD_lum_dm.T.filter(regex='mucosal')
LD_lum_muc_dm.shape
# Out:
# (69, 67)

# %%
LD_lum_muc_dm2 = LD_lum_muc_dm.copy()
LD_lum_muc_dm3 = LD_lum_muc_dm2.stack().reset_index()
LD_lum_muc_dm3.columns = ['Lumen','Mucosal','Value']
LD_lum_muc_dm3
# Out:
#                     Lumen                Mucosal     Value
# 0     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  1.022105
# 1     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.627475
# 2     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.696132
# 3     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.646791
# 4     lumen_ileum_LD_ZT22   mucosal_ileum_LD_ZT2  0.700223
# ...                   ...                    ...       ...
# 4618  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.653535
# 4619  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.643660
# 4620  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.704083
# 4621  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  0.743786
# 4622  lumen_ileum_LD_ZT10  mucosal_colon_LD_ZT22  1.090299
#
# [4623 rows x 3 columns]

# %%
LD_lum_muc_dm3['organ'] = LD_lum_muc_dm3['Lumen'].str.split('_').str[1] + "_" + LD_lum_muc_dm3['Mucosal'].str.split('_').str[1]
LD_lum_muc_dm3.organ.unique()
# Out:
# array(['ileum_ileum', 'ileum_jejunum', 'ileum_colon', 'colon_ileum',
#        'colon_jejunum', 'colon_colon', 'jejunum_ileum', 'jejunum_jejunum',
#        'jejunum_colon'], dtype=object)

# %%
LD_lum_muc_dm3['timepoints'] = LD_lum_muc_dm3['Lumen'].str.split('_').str[-1] + "_" + LD_lum_muc_dm3['Mucosal'].str.split('_').str[-1]
LD_lum_muc_dm3.timepoints.unique()
# Out:
# array(['ZT22_ZT2', 'ZT22_ZT6', 'ZT22_ZT10', 'ZT22_ZT14', 'ZT22_ZT18',
#        'ZT22_ZT22', 'ZT2_ZT2', 'ZT2_ZT6', 'ZT2_ZT10', 'ZT2_ZT14',
#        'ZT2_ZT18', 'ZT2_ZT22', 'ZT6_ZT2', 'ZT6_ZT6', 'ZT6_ZT10',
#        'ZT6_ZT14', 'ZT6_ZT18', 'ZT6_ZT22', 'ZT18_ZT2', 'ZT18_ZT6',
#        'ZT18_ZT10', 'ZT18_ZT14', 'ZT18_ZT18', 'ZT18_ZT22', 'ZT10_ZT2',
#        'ZT10_ZT6', 'ZT10_ZT10', 'ZT10_ZT14', 'ZT10_ZT18', 'ZT10_ZT22',
#        'ZT14_ZT2', 'ZT14_ZT6', 'ZT14_ZT10', 'ZT14_ZT14', 'ZT14_ZT18',
#        'ZT14_ZT22'], dtype=object)

# %%
LD_lum_muc_dm4 = LD_lum_muc_dm3.loc[LD_lum_muc_dm3['timepoints'].isin(zt_tps)]
LD_lum_muc_dm4
# Out:
#                     Lumen                  Mucosal     Value          organ  \
# 20    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.470506    ileum_ileum
# 21    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.594470    ileum_ileum
# 22    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.583236    ileum_ileum
# 43    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.243755  ileum_jejunum
# 44    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.755517  ileum_jejunum
# ...                   ...                      ...       ...            ...
# 4567  lumen_ileum_LD_ZT10    mucosal_ileum_LD_ZT10  0.291631    ileum_ileum
# 4587  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480301  ileum_jejunum
# 4588  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480678  ileum_jejunum
# 4589  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.528108  ileum_jejunum
# 4611  lumen_ileum_LD_ZT10    mucosal_colon_LD_ZT10  0.647024    ileum_colon
#
#      timepoints
# 20    ZT22_ZT22
# 21    ZT22_ZT22
# ...

# %%
LD_lum_muc_dm5 = LD_lum_muc_dm4.copy()
LD_lum_muc_dm5['ZT'] = LD_lum_muc_dm5['timepoints'].str.split('_').str[-1]
LD_lum_muc_dm5
# Out:
#                     Lumen                  Mucosal     Value          organ  \
# 20    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.470506    ileum_ileum
# 21    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.594470    ileum_ileum
# 22    lumen_ileum_LD_ZT22    mucosal_ileum_LD_ZT22  0.583236    ileum_ileum
# 43    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.243755  ileum_jejunum
# 44    lumen_ileum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.755517  ileum_jejunum
# ...                   ...                      ...       ...            ...
# 4567  lumen_ileum_LD_ZT10    mucosal_ileum_LD_ZT10  0.291631    ileum_ileum
# 4587  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480301  ileum_jejunum
# 4588  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.480678  ileum_jejunum
# 4589  lumen_ileum_LD_ZT10  mucosal_jejunum_LD_ZT10  0.528108  ileum_jejunum
# 4611  lumen_ileum_LD_ZT10    mucosal_colon_LD_ZT10  0.647024    ileum_colon
#
#      timepoints    ZT
# 20    ZT22_ZT22  ZT22
# ...

# %%
LD_LM_ileum = LD_lum_muc_dm5[LD_lum_muc_dm5['organ'] == 'ileum_ileum'].copy()
LD_LM_jejunum = LD_lum_muc_dm5[LD_lum_muc_dm5['organ'] == 'jejunum_jejunum'].copy()
LD_LM_colon = LD_lum_muc_dm5[LD_lum_muc_dm5['organ'] == 'colon_colon'].copy()

# %% [markdown]
# #### Ileum

# %%
LD_LM_ileum.head()
# Out:
#                    Lumen                Mucosal     Value        organ  \
# 20   lumen_ileum_LD_ZT22  mucosal_ileum_LD_ZT22  0.470506  ileum_ileum
# 21   lumen_ileum_LD_ZT22  mucosal_ileum_LD_ZT22  0.594470  ileum_ileum
# 22   lumen_ileum_LD_ZT22  mucosal_ileum_LD_ZT22  0.583236  ileum_ileum
# 469   lumen_ileum_LD_ZT2   mucosal_ileum_LD_ZT2  0.795018  ileum_ileum
# 470   lumen_ileum_LD_ZT2   mucosal_ileum_LD_ZT2  0.340979  ileum_ileum
#
#     timepoints    ZT
# 20   ZT22_ZT22  ZT22
# 21   ZT22_ZT22  ZT22
# 22   ZT22_ZT22  ZT22
# 469    ZT2_ZT2   ZT2
# 470    ZT2_ZT2   ZT2

# %%
LD_LM_ileum.Value.median()
# Out:
# 0.4499902753393743

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LD_LM_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LD_LM_ileum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Ileum LD wUF', fontsize=14)
plt.ylabel('BCD-Lum v Muc')
ax.axhline(0.4499902753393743, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_ileum_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# #### Jejunum

# %%
LD_LM_jejunum.head()
# Out:
#                      Lumen                  Mucosal     Value  \
# 177  lumen_jejunum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.499871
# 178  lumen_jejunum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.380131
# 179  lumen_jejunum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.074227
# 180  lumen_jejunum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.124904
# 181  lumen_jejunum_LD_ZT22  mucosal_jejunum_LD_ZT22  0.545662
#
#                organ timepoints    ZT
# 177  jejunum_jejunum  ZT22_ZT22  ZT22
# 178  jejunum_jejunum  ZT22_ZT22  ZT22
# 179  jejunum_jejunum  ZT22_ZT22  ZT22
# 180  jejunum_jejunum  ZT22_ZT22  ZT22
# 181  jejunum_jejunum  ZT22_ZT22  ZT22

# %%
LD_LM_jejunum.Value.median()
# Out:
# 0.5061979110581645

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LD_LM_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LD_LM_jejunum, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Jejunum LD wUF', fontsize=14)
plt.ylabel('BCD-Lum v Muc')
ax.axhline(0.5061979110581645, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_jejunum_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# #### Colon

# %%
LD_LM_colon.head()
# Out:
#                   Lumen               Mucosal     Value        organ  \
# 115  lumen_colon_LD_ZT2  mucosal_colon_LD_ZT2  0.583689  colon_colon
# 116  lumen_colon_LD_ZT2  mucosal_colon_LD_ZT2  0.572171  colon_colon
# 117  lumen_colon_LD_ZT2  mucosal_colon_LD_ZT2  0.169164  colon_colon
# 252  lumen_colon_LD_ZT6  mucosal_colon_LD_ZT6  0.240885  colon_colon
# 253  lumen_colon_LD_ZT6  mucosal_colon_LD_ZT6  0.281824  colon_colon
#
#     timepoints   ZT
# 115    ZT2_ZT2  ZT2
# 116    ZT2_ZT2  ZT2
# 117    ZT2_ZT2  ZT2
# 252    ZT6_ZT6  ZT6
# 253    ZT6_ZT6  ZT6

# %%
LD_LM_colon.Value.mean()
# Out:
# 0.5099110235276807

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=LD_LM_colon, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=LD_LM_colon, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Colon LD wUF')
plt.ylabel('BCD-Lum v Muc')
ax.axhline(0.5099110235276807, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/chen_colon_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### Colon v Jejunum (LD only)

# %%
lumen_dm = named4_SI_wUF_dm.filter(regex='lumen')
lumen_dm2 = LD.T.filter(regex='lumen')
lumen_dm2.head()
# Out:
# combined4           lumen_colon_RF_ZT10  lumen_colon_RF_ZT2  \
# lumen_ileum_LD_ZT2             1.907843            1.108910
# lumen_ileum_LD_ZT2             1.876845            1.080552
# lumen_ileum_LD_ZT2             1.899468            1.088504
# lumen_ileum_LD_ZT2             1.903837            1.109094
# lumen_ileum_LD_ZT2             2.071313            1.276226
#
# combined4           lumen_colon_DD_ZT6  lumen_colon_RF_ZT14  \
# lumen_ileum_LD_ZT2            0.891671             0.870061
# lumen_ileum_LD_ZT2            0.864561             0.842481
# lumen_ileum_LD_ZT2            0.869353             0.850573
# lumen_ileum_LD_ZT2            0.910986             0.892958
# lumen_ileum_LD_ZT2            1.051366             1.030349
#
# combined4           lumen_ileum_LD_ZT22  lumen_colon_LD_ZT2  \
# lumen_ileum_LD_ZT2             0.626761            0.857114
# lumen_ileum_LD_ZT2             0.610720            0.825087
# ...

# %%
colon_lum_dm = lumen_dm2.filter(regex='colon')
colon_jejunum_lum_dm2 = colon_lum_dm.T.filter(regex='jejunum')
colon_jejunum_lum_dm2.shape
# Out:
# (56, 72)

# %%
colon_jejunum_lum_dms = colon_jejunum_lum_dm2.copy()
colon_jejunum_lum_dms2 = colon_jejunum_lum_dms.stack().reset_index()
colon_jejunum_lum_dms2.columns = ['colon','jejunum','Value']
colon_jejunum_lum_dms2
# Out:
#                     colon                     jejunum     Value
# 0     lumen_colon_RF_ZT10        lumen_jejunum_LD_ZT2  1.919965
# 1     lumen_colon_RF_ZT10        lumen_jejunum_LD_ZT2  1.710058
# 2     lumen_colon_RF_ZT10        lumen_jejunum_LD_ZT2  1.859685
# 3     lumen_colon_RF_ZT10        lumen_jejunum_LD_ZT2  1.979398
# 4     lumen_colon_RF_ZT10        lumen_jejunum_LD_ZT6  1.698205
# ...                   ...                         ...       ...
# 4027  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT22  0.542993
# 4028  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT22  0.736516
# 4029  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT22  0.750261
# 4030  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT22  0.615344
# 4031  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT22  0.759641
#
# [4032 rows x 3 columns]

# %%
colon_jejunum_lum_dms2['timepoints'] = colon_jejunum_lum_dms2['colon'].str.split('_').str[-1] + "_" + colon_jejunum_lum_dms2['jejunum'].str.split('_').str[-1]
colon_jejunum_lum_dms2.timepoints.unique()
# Out:
# array(['ZT10_ZT2', 'ZT10_ZT6', 'ZT10_ZT10', 'ZT10_ZT14', 'ZT10_ZT18',
#        'ZT10_ZT22', 'ZT2_ZT2', 'ZT2_ZT6', 'ZT2_ZT10', 'ZT2_ZT14',
#        'ZT2_ZT18', 'ZT2_ZT22', 'ZT6_ZT2', 'ZT6_ZT6', 'ZT6_ZT10',
#        'ZT6_ZT14', 'ZT6_ZT18', 'ZT6_ZT22', 'ZT14_ZT2', 'ZT14_ZT6',
#        'ZT14_ZT10', 'ZT14_ZT14', 'ZT14_ZT18', 'ZT14_ZT22', 'ZT22_ZT2',
#        'ZT22_ZT6', 'ZT22_ZT10', 'ZT22_ZT14', 'ZT22_ZT18', 'ZT22_ZT22',
#        'ZT18_ZT2', 'ZT18_ZT6', 'ZT18_ZT10', 'ZT18_ZT14', 'ZT18_ZT18',
#        'ZT18_ZT22'], dtype=object)

# %%
colon_jejunum_lum_dms3 = colon_jejunum_lum_dms2.loc[colon_jejunum_lum_dms2['timepoints'].isin(zt_tps)]
colon_jejunum_lum_dms3
# Out:
#                     colon                     jejunum     Value timepoints
# 9     lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.948358  ZT10_ZT10
# 10    lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.844232  ZT10_ZT10
# 11    lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.742995  ZT10_ZT10
# 32    lumen_colon_RF_ZT10     mucosal_jejunum_LD_ZT10  1.737281  ZT10_ZT10
# 33    lumen_colon_RF_ZT10     mucosal_jejunum_LD_ZT10  1.859317  ZT10_ZT10
# ...                   ...                         ...       ...        ...
# 3996  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.662172  ZT14_ZT14
# 3997  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.834880  ZT14_ZT14
# 3998  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.771214  ZT14_ZT14
# 4020  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT14  0.751366  ZT14_ZT14
# 4021  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT14  0.442308  ZT14_ZT14
#
# [672 rows x 4 columns]

# %%
colon_jejunum_lum_dms4 = colon_jejunum_lum_dms3.copy()
colon_jejunum_lum_dms4['ZT'] = colon_jejunum_lum_dms4['timepoints'].str.split('_').str[-1]
colon_jejunum_lum_dms4
# Out:
#                     colon                     jejunum     Value timepoints  \
# 9     lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.948358  ZT10_ZT10
# 10    lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.844232  ZT10_ZT10
# 11    lumen_colon_RF_ZT10       lumen_jejunum_LD_ZT10  1.742995  ZT10_ZT10
# 32    lumen_colon_RF_ZT10     mucosal_jejunum_LD_ZT10  1.737281  ZT10_ZT10
# 33    lumen_colon_RF_ZT10     mucosal_jejunum_LD_ZT10  1.859317  ZT10_ZT10
# ...                   ...                         ...       ...        ...
# 3996  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.662172  ZT14_ZT14
# 3997  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.834880  ZT14_ZT14
# 3998  lumen_colon_DD_ZT14     mucosal_jejunum_LD_ZT14  0.771214  ZT14_ZT14
# 4020  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT14  0.751366  ZT14_ZT14
# 4021  lumen_colon_DD_ZT14  epithelium_jejunum_LD_ZT14  0.442308  ZT14_ZT14
#
#         ZT
# 9     ZT10
# 10    ZT10
# 11    ZT10
# 32    ZT10
# ...

# %%
colon_jejunum_lum_dms4.Value.mean()
# Out:
# 0.8765714475228976

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=colon_jejunum_lum_dms4, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=colon_jejunum_lum_dms4, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Luminal Contents', fontsize=14)
plt.ylabel('wUF BCD Jejunum-v-Colon')
ax.axhline(0.801909399398105, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
#plt.savefig('../figures/chen_jejunum_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### Colon v Jejunum (LD only)

# %%
LD_lum_dm = LD2.filter(regex='lumen')
LD_lum_dm2 = LD_lum_dm.T.filter(regex='lumen')
LD_lum_dm2.shape
# Out:
# (69, 69)

# %%
colon_LD_lum_dm = LD_lum_dm2.filter(regex='colon')
colon_jejunum_LD_lum_dm2 = colon_LD_lum_dm.T.filter(regex='jejunum')
colon_jejunum_LD_lum_dm2.shape
# Out:
# (19, 24)

# %%
colon_jejunum_LD_lum_dms = colon_jejunum_LD_lum_dm2.copy()
colon_jejunum_LD_lum_dms2 = colon_jejunum_LD_lum_dms.stack().reset_index()
colon_jejunum_LD_lum_dms2.columns = ['colon','jejunum','Value']
colon_jejunum_LD_lum_dms2
# Out:
#                    colon                jejunum     Value
# 0     lumen_colon_LD_ZT2  lumen_jejunum_LD_ZT22  0.941144
# 1     lumen_colon_LD_ZT2  lumen_jejunum_LD_ZT18  0.565252
# 2     lumen_colon_LD_ZT2  lumen_jejunum_LD_ZT14  1.011644
# 3     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.983649
# 4     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.926249
# ..                   ...                    ...       ...
# 451  lumen_colon_LD_ZT22   lumen_jejunum_LD_ZT6  1.652327
# 452  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT10  1.461215
# 453  lumen_colon_LD_ZT22   lumen_jejunum_LD_ZT6  1.512122
# 454  lumen_colon_LD_ZT22   lumen_jejunum_LD_ZT2  1.514224
# 455  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT10  1.614201
#
# [456 rows x 3 columns]

# %%
colon_jejunum_LD_lum_dms2['timepoints'] = colon_jejunum_LD_lum_dms2['colon'].str.split('_').str[-1] + "_" + colon_jejunum_LD_lum_dms2['jejunum'].str.split('_').str[-1]
colon_jejunum_LD_lum_dms2.timepoints.unique()
# Out:
# array(['ZT2_ZT22', 'ZT2_ZT18', 'ZT2_ZT14', 'ZT2_ZT2', 'ZT2_ZT6',
#        'ZT2_ZT10', 'ZT6_ZT22', 'ZT6_ZT18', 'ZT6_ZT14', 'ZT6_ZT2',
#        'ZT6_ZT6', 'ZT6_ZT10', 'ZT10_ZT22', 'ZT10_ZT18', 'ZT10_ZT14',
#        'ZT10_ZT2', 'ZT10_ZT6', 'ZT10_ZT10', 'ZT14_ZT22', 'ZT14_ZT18',
#        'ZT14_ZT14', 'ZT14_ZT2', 'ZT14_ZT6', 'ZT14_ZT10', 'ZT22_ZT22',
#        'ZT22_ZT18', 'ZT22_ZT14', 'ZT22_ZT2', 'ZT22_ZT6', 'ZT22_ZT10'],
#       dtype=object)

# %%
colon_jejunum_LD_lum_dms3 = colon_jejunum_LD_lum_dms2.loc[colon_jejunum_LD_lum_dms2['timepoints'].isin(zt_tps)]
colon_jejunum_LD_lum_dms3
# Out:
#                    colon                jejunum     Value timepoints
# 3     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.983649    ZT2_ZT2
# 4     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.926249    ZT2_ZT2
# 18    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.630918    ZT2_ZT2
# 22    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.868220    ZT2_ZT2
# 27    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.939657    ZT2_ZT2
# ..                   ...                    ...       ...        ...
# 425  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  0.413222  ZT22_ZT22
# 432  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.561659  ZT22_ZT22
# 444  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.536765  ZT22_ZT22
# 446  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.541095  ZT22_ZT22
# 449  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.423325  ZT22_ZT22
#
# [76 rows x 4 columns]

# %%
colon_jejunum_LD_lum_dms4 = colon_jejunum_LD_lum_dms3.copy()
colon_jejunum_LD_lum_dms4['ZT'] = colon_jejunum_LD_lum_dms4['timepoints'].str.split('_').str[-1]
colon_jejunum_LD_lum_dms4
# Out:
#                    colon                jejunum     Value timepoints    ZT
# 3     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.983649    ZT2_ZT2   ZT2
# 4     lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.926249    ZT2_ZT2   ZT2
# 18    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.630918    ZT2_ZT2   ZT2
# 22    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.868220    ZT2_ZT2   ZT2
# 27    lumen_colon_LD_ZT2   lumen_jejunum_LD_ZT2  0.939657    ZT2_ZT2   ZT2
# ..                   ...                    ...       ...        ...   ...
# 425  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  0.413222  ZT22_ZT22  ZT22
# 432  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.561659  ZT22_ZT22  ZT22
# 444  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.536765  ZT22_ZT22  ZT22
# 446  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.541095  ZT22_ZT22  ZT22
# 449  lumen_colon_LD_ZT22  lumen_jejunum_LD_ZT22  1.423325  ZT22_ZT22  ZT22
#
# [76 rows x 5 columns]

# %%
colon_jejunum_LD_lum_dms4.Value.mean()
# Out:
# 0.801909399398105

# %%
ax = sns.boxplot(x="ZT", y="Value", palette="BuGn",
                 data=colon_jejunum_LD_lum_dms4, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
ax = sns.stripplot(x="ZT", y="Value", palette="BuGn", edgecolor='k', linewidth=1, size=9,
                   data=colon_jejunum_LD_lum_dms4, order=['ZT2', 'ZT6', 'ZT10', 'ZT14', 'ZT18', 'ZT22'])
plt.title('Luminal Contents LD', fontsize=14)
plt.ylabel('wUF BCD Jejunum-v-Colon')
ax.axhline(0.801909399398105, color='k', ls='--')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
#plt.savefig('../figures/chen_jejunum_LD_lummuc_wUF_boxplot.svg', dpi=300, bbox_inches="tight")
