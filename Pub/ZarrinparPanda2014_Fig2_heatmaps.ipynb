# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Cecum

# %%
TRF_metadata = pd.read_csv('../data/TRF/CA_TRF_metadata.txt', 
                            sep='\t', usecols=['#SampleID', 'group_time'], index_col=0)
TRF_metadata.head()
# Out:
#           group_time
# #SampleID
# FA1a           FA_13
# FA1b           FA_13
# FA1c           FA_13
# FA2a           FA_17
# FA2b           FA_17

# %%
TRF_wUF_dm = pd.read_csv('../data/TRF/TRF_cecal_weighted_UF_dm.txt', sep='\t', index_col=0)
TRF_wUF_dm.head()
#no NT
# Out:
#           FA1a      FA1b      FA1c      FA2a      FA2b      FA2c      FA3a  \
# FA1a  0.000000  0.143385  0.106675  0.188869  0.219044  0.174871  0.204339
# FA1b  0.143385  0.000000  0.086490  0.158030  0.177583  0.149456  0.172800
# FA1c  0.106675  0.086490  0.000000  0.126569  0.147011  0.124658  0.148568
# FA2a  0.188869  0.158030  0.126569  0.000000  0.055942  0.059646  0.071387
# FA2b  0.219044  0.177583  0.147011  0.055942  0.000000  0.105259  0.097744
#
#           FA3b      FA3c      FA4a  ...      NA3c      NA4a      NA4b  \
# FA1a  0.170195  0.184893  0.174890  ...  0.490090  0.314505  0.496955
# FA1b  0.124692  0.168069  0.159387  ...  0.589128  0.401702  0.604318
# FA1c  0.108913  0.132834  0.113626  ...  0.570561  0.374671  0.579982
# FA2a  0.089067  0.069608  0.055440  ...  0.660115  0.465461  0.661741
# FA2b  0.126038  0.115500  0.083209  ...  0.673820  0.476631  0.672187
#
#           NA4c      NA5a      NA5b      NA5c      NA6a      NA6b      NA6c
# FA1a  0.284650  0.675157  0.549224  0.389871  0.673196  0.766413  0.410509
# FA1b  0.262257  0.666644  0.654780  0.467881  0.667750  0.767752  0.464017
# FA1c  0.231128  0.642022  0.635572  0.466110  0.637492  0.731064  0.489926
# FA2a  0.234453  0.642681  0.721615  0.561920  0.671167  0.729916  0.581241
# FA2b  0.223947  0.660367  0.736724  0.573369  0.687231  0.747243  0.594427
#
# [5 rows x 54 columns]

# %%
named_TRF_wUF_dm = pd.merge(TRF_metadata, TRF_wUF_dm, left_index=True, right_index=True)
named_TRF_wUF_dm.head()
# Out:
#      group_time      FA1a      FA1b      FA1c      FA2a      FA2b      FA2c  \
# FA1a      FA_13  0.000000  0.143385  0.106675  0.188869  0.219044  0.174871
# FA1b      FA_13  0.143385  0.000000  0.086490  0.158030  0.177583  0.149456
# FA1c      FA_13  0.106675  0.086490  0.000000  0.126569  0.147011  0.124658
# FA2a      FA_17  0.188869  0.158030  0.126569  0.000000  0.055942  0.059646
# FA2b      FA_17  0.219044  0.177583  0.147011  0.055942  0.000000  0.105259
#
#           FA3a      FA3b      FA3c  ...      NA3c      NA4a      NA4b  \
# FA1a  0.204339  0.170195  0.184893  ...  0.490090  0.314505  0.496955
# FA1b  0.172800  0.124692  0.168069  ...  0.589128  0.401702  0.604318
# FA1c  0.148568  0.108913  0.132834  ...  0.570561  0.374671  0.579982
# FA2a  0.071387  0.089067  0.069608  ...  0.660115  0.465461  0.661741
# FA2b  0.097744  0.126038  0.115500  ...  0.673820  0.476631  0.672187
#
#           NA4c      NA5a      NA5b      NA5c      NA6a      NA6b      NA6c
# FA1a  0.284650  0.675157  0.549224  0.389871  0.673196  0.766413  0.410509
# FA1b  0.262257  0.666644  0.654780  0.467881  0.667750  0.767752  0.464017
# FA1c  0.231128  0.642022  0.635572  0.466110  0.637492  0.731064  0.489926
# FA2a  0.234453  0.642681  0.721615  0.561920  0.671167  0.729916  0.581241
# FA2b  0.223947  0.660367  0.736724  0.573369  0.687231  0.747243  0.594427
#
# [5 rows x 55 columns]

# %%
named2_TRF_wUF_dm = named_TRF_wUF_dm.set_index('group_time')

# %%
Named_TRF_wUF_dm = named_TRF_wUF_dm[['group_time']].copy()
Named_TRF_wUF_dm.head()
# Out:
#      group_time
# FA1a      FA_13
# FA1b      FA_13
# FA1c      FA_13
# FA2a      FA_17
# FA2b      FA_17

# %%
named3_TRF_wUF_dm = pd.merge(named2_TRF_wUF_dm.T, Named_TRF_wUF_dm, left_index=True, right_index=True)
named4_TRF_wUF_dm = named3_TRF_wUF_dm.set_index('group_time')
named4_TRF_wUF_dm.head()
# Out:
#                FA_13     FA_13     FA_13     FA_17     FA_17     FA_17  \
# group_time
# FA_13       0.000000  0.143385  0.106675  0.188869  0.219044  0.174871
# FA_13       0.143385  0.000000  0.086490  0.158030  0.177583  0.149456
# FA_13       0.106675  0.086490  0.000000  0.126569  0.147011  0.124658
# FA_17       0.188869  0.158030  0.126569  0.000000  0.055942  0.059646
# FA_17       0.219044  0.177583  0.147011  0.055942  0.000000  0.105259
#
#                FA_21     FA_21     FA_21      FA_1  ...     NA_21      NA_1  \
# group_time                                          ...
# FA_13       0.204339  0.170195  0.184893  0.174890  ...  0.490090  0.314505
# FA_13       0.172800  0.124692  0.168069  0.159387  ...  0.589128  0.401702
# FA_13       0.148568  0.108913  0.132834  0.113626  ...  0.570561  0.374671
# FA_17       0.071387  0.089067  0.069608  0.055440  ...  0.660115  0.465461
# FA_17       0.097744  0.126038  0.115500  0.083209  ...  0.673820  0.476631
#
#                 NA_1      NA_1      NA_5      NA_5      NA_5      NA_9  \
# group_time
# FA_13       0.496955  0.284650  0.675157  0.549224  0.389871  0.673196
# FA_13       0.604318  0.262257  0.666644  0.654780  0.467881  0.667750
# FA_13       0.579982  0.231128  0.642022  0.635572  0.466110  0.637492
# FA_17       0.661741  0.234453  0.642681  0.721615  0.561920  0.671167
# FA_17       0.672187  0.223947  0.660367  0.736724  0.573369  0.687231
#
#                 NA_9      NA_9
# group_time
# FA_13       0.766413  0.410509
# FA_13       0.767752  0.464017
# FA_13       0.731064  0.489926
# FA_17       0.729916  0.581241
# FA_17       0.747243  0.594427
#
# [5 rows x 54 columns]

# %% [markdown]
# ### all HFD, compare ad lib and TRF

# %%
named5_TRF_wUF_dm = named4_TRF_wUF_dm.filter(regex='FA')
named6_TRF_wUF_dm = named5_TRF_wUF_dm.T.filter(regex='FT')
named6_TRF_wUF_dm.head()
# Out:
# group_time     FT_13     FT_13     FT_13     FT_17     FT_17     FT_17  \
# FA_13       0.164956  0.165768  0.161452  0.186035  0.172620  0.244428
# FA_13       0.177751  0.160263  0.165725  0.161843  0.160204  0.199976
# FA_13       0.111355  0.118258  0.128152  0.117143  0.109245  0.173678
# FA_17       0.108276  0.096864  0.086881  0.070941  0.065558  0.133084
# FA_17       0.115893  0.119936  0.133461  0.075480  0.083895  0.132886
#
# group_time     FT_21     FT_21     FT_21      FT_1      FT_1      FT_1  \
# FA_13       0.206680  0.208151  0.171414  0.177868  0.236502  0.223120
# FA_13       0.168628  0.182442  0.166167  0.173566  0.179749  0.141572
# FA_13       0.140485  0.148126  0.124032  0.114803  0.182944  0.146658
# FA_17       0.082061  0.143798  0.057162  0.075688  0.167216  0.114020
# FA_17       0.083974  0.131245  0.101065  0.106823  0.190337  0.154751
#
# group_time      FT_5      FT_5      FT_5      FT_9      FT_9      FT_9
# FA_13       0.166043  0.166565  0.165209  0.203838  0.193010  0.164756
# FA_13       0.145910  0.159408  0.142134  0.153236  0.179957  0.159881
# FA_13       0.101192  0.116437  0.097981  0.162355  0.134878  0.126107
# FA_17       0.072402  0.080060  0.067086  0.146882  0.135531  0.131996
# FA_17       0.085921  0.113191  0.090259  0.180441  0.142632  0.159268

# %%
mean_TRF_wUF_dm = named6_TRF_wUF_dm.groupby(level=0).mean()
mean_TRF_wUF_dm = mean_TRF_wUF_dm.reindex(index = ['FA_1', 'FA_5', 'FA_9', 'FA_13', 'FA_17', 'FA_21'])
mean2_TRF_wUF_dm = mean_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
mean2_TRF_wUF_dm = mean2_TRF_wUF_dm.reindex(index = ['FT_1', 'FT_5', 'FT_9', 'FT_13', 'FT_17', 'FT_21'])
mean2_TRF_wUF_dm
# Out:
#                 FA_1      FA_5      FA_9     FA_13     FA_17     FA_21
# group_time
# FT_1        0.146629  0.138094  0.138334  0.175198  0.126826  0.119969
# FT_5        0.133967  0.100785  0.099933  0.140098  0.082589  0.078182
# FT_9        0.134751  0.113095  0.105802  0.164224  0.138566  0.124173
# FT_13       0.140043  0.110795  0.100486  0.150409  0.101119  0.103627
# FT_17       0.162063  0.146818  0.139741  0.169464  0.102296  0.098065
# FT_21       0.164954  0.143098  0.140774  0.168458  0.104561  0.095656

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(mean2_TRF_wUF_dm, cmap='winter', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.075, vmax=0.175, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances Ad Lib vs TRF (HFD)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/TRF_wUF_cecum_time_mean_heatmap.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### all adlib, compare NCD and HFD

# %%
diet5_TRF_wUF_dm = named4_TRF_wUF_dm.filter(regex='FA')
diet6_TRF_wUF_dm = diet5_TRF_wUF_dm.T.filter(regex='NA')
diet6_TRF_wUF_dm.head()
# Out:
# group_time     NA_13     NA_13     NA_13     NA_17     NA_17     NA_17  \
# FA_13       0.369248  0.307060  0.310653  0.212640  0.429741  0.312540
# FA_13       0.362920  0.292321  0.351327  0.287290  0.536834  0.414762
# FA_13       0.314625  0.252427  0.313642  0.260348  0.504095  0.385974
# FA_17       0.344212  0.285869  0.385945  0.344885  0.594207  0.478701
# FA_17       0.355459  0.286987  0.397180  0.349091  0.596086  0.487323
#
# group_time     NA_21     NA_21     NA_21      NA_1      NA_1      NA_1  \
# FA_13       0.247535  0.234282  0.490090  0.314505  0.496955  0.284650
# FA_13       0.219438  0.218638  0.589128  0.401702  0.604318  0.262257
# FA_13       0.183161  0.182176  0.570561  0.374671  0.579982  0.231128
# FA_17       0.187042  0.205991  0.660115  0.465461  0.661741  0.234453
# FA_17       0.180218  0.195621  0.673820  0.476631  0.672187  0.223947
#
# group_time      NA_5      NA_5      NA_5      NA_9      NA_9      NA_9
# FA_13       0.675157  0.549224  0.389871  0.673196  0.766413  0.410509
# FA_13       0.666644  0.654780  0.467881  0.667750  0.767752  0.464017
# FA_13       0.642022  0.635572  0.466110  0.637492  0.731064  0.489926
# FA_17       0.642681  0.721615  0.561920  0.671167  0.729916  0.581241
# FA_17       0.660367  0.736724  0.573369  0.687231  0.747243  0.594427

# %%
dmean_TRF_wUF_dm = diet6_TRF_wUF_dm.groupby(level=0).mean()
dmean_TRF_wUF_dm = dmean_TRF_wUF_dm.reindex(index = ['FA_1', 'FA_5', 'FA_9', 'FA_13', 'FA_17', 'FA_21'])
dmean2_TRF_wUF_dm = dmean_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
dmean2_TRF_wUF_dm = dmean2_TRF_wUF_dm.reindex(index = ['NA_1', 'NA_5', 'NA_9', 'NA_13', 'NA_17', 'NA_21'])
dmean2_TRF_wUF_dm
# Out:
#                 FA_1      FA_5      FA_9     FA_13     FA_17     FA_21
# group_time
# NA_1        0.454867  0.441164  0.436021  0.394463  0.457578  0.452263
# NA_5        0.608767  0.598466  0.591579  0.571918  0.641232  0.636666
# NA_9        0.631364  0.619300  0.614402  0.623124  0.659660  0.655671
# NA_13       0.345070  0.330594  0.327652  0.319358  0.345391  0.339210
# NA_17       0.456670  0.450827  0.439631  0.371580  0.475575  0.472557
# NA_21       0.365727  0.349109  0.344892  0.326112  0.354833  0.346363

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dmean2_TRF_wUF_dm, cmap='RdPu_r', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.325, vmax=0.675, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances NCD vs HFD (ad libitum)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/TRF_wUF_cecum_diet_mean_heatmap.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### compare NA vs FT

# %%
f5_TRF_wUF_dm = named4_TRF_wUF_dm.filter(regex='FT')
f6_TRF_wUF_dm = f5_TRF_wUF_dm.T.filter(regex='NA')
f6_TRF_wUF_dm.head()
# Out:
# group_time     NA_13     NA_13     NA_13     NA_17     NA_17     NA_17  \
# FT_13       0.313832  0.230716  0.346472  0.300673  0.538045  0.432975
# FT_13       0.348679  0.295144  0.371322  0.350367  0.568883  0.454293
# FT_13       0.356052  0.307579  0.371755  0.363361  0.577655  0.459146
# FT_17       0.326993  0.250418  0.367334  0.308117  0.556300  0.445294
# FT_17       0.325196  0.256830  0.365303  0.314021  0.561971  0.448510
#
# group_time     NA_21     NA_21     NA_21      NA_1      NA_1      NA_1  \
# FT_13       0.161109  0.153801  0.622798  0.424439  0.619368  0.185444
# FT_13       0.206215  0.217414  0.632254  0.459894  0.644037  0.245573
# FT_13       0.219382  0.230506  0.634250  0.462998  0.642834  0.257821
# FT_17       0.153776  0.163518  0.645135  0.445813  0.638164  0.192657
# FT_17       0.163043  0.173234  0.642788  0.445529  0.639536  0.207987
#
# group_time      NA_5      NA_5      NA_5      NA_9      NA_9      NA_9
# FT_13       0.624567  0.685838  0.522832  0.661646  0.714655  0.545618
# FT_13       0.618642  0.699023  0.529361  0.644692  0.708397  0.546237
# FT_13       0.618066  0.697594  0.534836  0.644749  0.701658  0.551147
# FT_17       0.631406  0.706860  0.545485  0.659631  0.720054  0.567014
# FT_17       0.630283  0.705942  0.541738  0.656376  0.717344  0.564565

# %%
fmean_TRF_wUF_dm = f6_TRF_wUF_dm.groupby(level=0).mean()
fmean_TRF_wUF_dm = fmean_TRF_wUF_dm.reindex(index = ['FT_1', 'FT_5', 'FT_9', 'FT_13', 'FT_17', 'FT_21'])
fmean2_TRF_wUF_dm = fmean_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
fmean2_TRF_wUF_dm = fmean2_TRF_wUF_dm.reindex(index = ['NA_1', 'NA_5', 'NA_9', 'NA_13', 'NA_17', 'NA_21'])
fmean2_TRF_wUF_dm
# Out:
#                 FT_1      FT_5      FT_9     FT_13     FT_17     FT_21
# group_time
# NA_1        0.475703  0.430191  0.439443  0.438045  0.437233  0.426708
# NA_5        0.643955  0.620558  0.610084  0.614529  0.638075  0.630246
# NA_9        0.654962  0.641378  0.626999  0.635422  0.657902  0.653369
# NA_13       0.360843  0.318299  0.328207  0.326839  0.326651  0.321546
# NA_17       0.491026  0.443959  0.462672  0.449489  0.452430  0.450639
# NA_21       0.377974  0.329742  0.353603  0.341970  0.324585  0.321568

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(fmean2_TRF_wUF_dm, cmap='Oranges_r', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.26, vmax=0.665, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances NCD (ad libitum) vs HFD (TRF)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/NAvFT_wUF_cecum_diet_mean_heatmap.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# # Ileum

# %%
TRF_metadata.head()
# Out:
#           group_time
# #SampleID
# FA1a           FA_13
# FA1b           FA_13
# FA1c           FA_13
# FA2a           FA_17
# FA2b           FA_17

# %%
TRF_ileum_wUF_dm = pd.read_csv('../data/TRF/TRF_ileum_weighted_UF_dm.txt', sep='\t', index_col=0)
TRF_ileum_wUF_dm.head()
# Out:
#           FA1a      FA1b      FA1c      FA2a      FA2b      FA2c      FA3a  \
# FA1a  0.000000  0.369657  0.266580  0.076788  0.249360  0.121077  0.168362
# FA1b  0.369657  0.000000  0.147143  0.401837  0.462808  0.385000  0.358886
# FA1c  0.266580  0.147143  0.000000  0.295277  0.380656  0.270503  0.228755
# FA2a  0.076788  0.401837  0.295277  0.000000  0.224651  0.078346  0.163151
# FA2b  0.249360  0.462808  0.380656  0.224651  0.000000  0.208107  0.299370
#
#           FA3b      FA3c      FA4a  ...      NA3c      NA4a      NA4b  \
# FA1a  0.183448  0.090670  0.125136  ...  0.291978  0.477433  0.437833
# FA1b  0.348773  0.415740  0.354017  ...  0.441277  0.339326  0.617206
# FA1c  0.219187  0.304509  0.249875  ...  0.346492  0.325757  0.520653
# FA2a  0.213184  0.052889  0.099374  ...  0.272744  0.497318  0.469467
# FA2b  0.339172  0.228248  0.262476  ...  0.315471  0.570422  0.550658
#
#           NA4c      NA5a      NA5b      NA5c      NA6a      NA6b      NA6c
# FA1a  0.370452  0.543184  0.622351  0.344142  0.522605  0.447945  0.667068
# FA1b  0.534875  0.555037  0.680036  0.513829  0.597474  0.483609  0.665792
# FA1c  0.440422  0.518174  0.638573  0.414063  0.515990  0.454896  0.647930
# FA2a  0.373235  0.565619  0.657914  0.346080  0.523634  0.447431  0.676499
# FA2b  0.423504  0.617261  0.739033  0.381223  0.587588  0.514375  0.744851
#
# [5 rows x 54 columns]

# %%
ileum_TRF_wUF_dm = pd.merge(TRF_metadata, TRF_ileum_wUF_dm, left_index=True, right_index=True)
ileum_TRF_wUF_dm.head()
# Out:
#      group_time      FA1a      FA1b      FA1c      FA2a      FA2b      FA2c  \
# FA1a      FA_13  0.000000  0.369657  0.266580  0.076788  0.249360  0.121077
# FA1b      FA_13  0.369657  0.000000  0.147143  0.401837  0.462808  0.385000
# FA1c      FA_13  0.266580  0.147143  0.000000  0.295277  0.380656  0.270503
# FA2a      FA_17  0.076788  0.401837  0.295277  0.000000  0.224651  0.078346
# FA2b      FA_17  0.249360  0.462808  0.380656  0.224651  0.000000  0.208107
#
#           FA3a      FA3b      FA3c  ...      NA3c      NA4a      NA4b  \
# FA1a  0.168362  0.183448  0.090670  ...  0.291978  0.477433  0.437833
# FA1b  0.358886  0.348773  0.415740  ...  0.441277  0.339326  0.617206
# FA1c  0.228755  0.219187  0.304509  ...  0.346492  0.325757  0.520653
# FA2a  0.163151  0.213184  0.052889  ...  0.272744  0.497318  0.469467
# FA2b  0.299370  0.339172  0.228248  ...  0.315471  0.570422  0.550658
#
#           NA4c      NA5a      NA5b      NA5c      NA6a      NA6b      NA6c
# FA1a  0.370452  0.543184  0.622351  0.344142  0.522605  0.447945  0.667068
# FA1b  0.534875  0.555037  0.680036  0.513829  0.597474  0.483609  0.665792
# FA1c  0.440422  0.518174  0.638573  0.414063  0.515990  0.454896  0.647930
# FA2a  0.373235  0.565619  0.657914  0.346080  0.523634  0.447431  0.676499
# FA2b  0.423504  0.617261  0.739033  0.381223  0.587588  0.514375  0.744851
#
# [5 rows x 55 columns]

# %%
ileum2_TRF_wUF_dm = ileum_TRF_wUF_dm.set_index('group_time')

# %%
ileum_TRF_wUF_dm = ileum_TRF_wUF_dm[['group_time']].copy()
ileum_TRF_wUF_dm.head()
# Out:
#      group_time
# FA1a      FA_13
# FA1b      FA_13
# FA1c      FA_13
# FA2a      FA_17
# FA2b      FA_17

# %%
ileum3_TRF_wUF_dm = pd.merge(ileum2_TRF_wUF_dm.T, ileum_TRF_wUF_dm, left_index=True, right_index=True)
ileum4_TRF_wUF_dm = ileum3_TRF_wUF_dm.set_index('group_time')
ileum4_TRF_wUF_dm.head()
# Out:
#                FA_13     FA_13     FA_13     FA_17     FA_17     FA_17  \
# group_time
# FA_13       0.000000  0.369657  0.266580  0.076788  0.249360  0.121077
# FA_13       0.369657  0.000000  0.147143  0.401837  0.462808  0.385000
# FA_13       0.266580  0.147143  0.000000  0.295277  0.380656  0.270503
# FA_17       0.076788  0.401837  0.295277  0.000000  0.224651  0.078346
# FA_17       0.249360  0.462808  0.380656  0.224651  0.000000  0.208107
#
#                FA_21     FA_21     FA_21      FA_1  ...     NA_21      NA_1  \
# group_time                                          ...
# FA_13       0.168362  0.183448  0.090670  0.125136  ...  0.291978  0.477433
# FA_13       0.358886  0.348773  0.415740  0.354017  ...  0.441277  0.339326
# FA_13       0.228755  0.219187  0.304509  0.249875  ...  0.346492  0.325757
# FA_17       0.163151  0.213184  0.052889  0.099374  ...  0.272744  0.497318
# FA_17       0.299370  0.339172  0.228248  0.262476  ...  0.315471  0.570422
#
#                 NA_1      NA_1      NA_5      NA_5      NA_5      NA_9  \
# group_time
# FA_13       0.437833  0.370452  0.543184  0.622351  0.344142  0.522605
# FA_13       0.617206  0.534875  0.555037  0.680036  0.513829  0.597474
# FA_13       0.520653  0.440422  0.518174  0.638573  0.414063  0.515990
# FA_17       0.469467  0.373235  0.565619  0.657914  0.346080  0.523634
# FA_17       0.550658  0.423504  0.617261  0.739033  0.381223  0.587588
#
#                 NA_9      NA_9
# group_time
# FA_13       0.447945  0.667068
# FA_13       0.483609  0.665792
# FA_13       0.454896  0.647930
# FA_17       0.447431  0.676499
# FA_17       0.514375  0.744851
#
# [5 rows x 54 columns]

# %% [markdown]
# ### all HFD, compare ad lib and TRF

# %%
ileum5_TRF_wUF_dm = ileum4_TRF_wUF_dm.filter(regex='FA')
ileum6_TRF_wUF_dm = ileum5_TRF_wUF_dm.T.filter(regex='FT')
ileum6_TRF_wUF_dm.head()
# Out:
# group_time     FT_13     FT_13     FT_13     FT_17     FT_17     FT_17  \
# FA_13       0.330016  0.306774  0.290310  0.326386  0.304167  0.342327
# FA_13       0.482345  0.458807  0.413698  0.473588  0.332300  0.181255
# FA_13       0.390533  0.366529  0.322714  0.386500  0.245154  0.169777
# FA_17       0.292441  0.289942  0.290671  0.293750  0.304742  0.365138
# FA_17       0.164471  0.189493  0.205015  0.143879  0.268724  0.409126
#
# group_time     FT_21     FT_21     FT_21      FT_1      FT_1      FT_1  \
# FA_13       0.310198  0.150760  0.119349  0.274759  0.115772  0.113616
# FA_13       0.214396  0.315943  0.366930  0.211002  0.329259  0.382772
# FA_13       0.160621  0.212002  0.265674  0.114299  0.229768  0.274627
# FA_17       0.353151  0.165856  0.133994  0.293165  0.109196  0.087156
# FA_17       0.364114  0.288218  0.242189  0.376969  0.240030  0.176950
#
# group_time      FT_5      FT_5      FT_5      FT_9      FT_9      FT_9
# FA_13       0.175936  0.192966  0.086803  0.150664  0.188823  0.176298
# FA_13       0.273096  0.307363  0.389335  0.343036  0.315734  0.341067
# FA_13       0.199231  0.240408  0.301605  0.245432  0.244259  0.240160
# FA_17       0.189854  0.210076  0.044822  0.138370  0.195524  0.188166
# FA_17       0.352630  0.366432  0.234736  0.278326  0.329634  0.322430

# %%
meani_TRF_wUF_dm = ileum6_TRF_wUF_dm.groupby(level=0).mean()
meani_TRF_wUF_dm = meani_TRF_wUF_dm.reindex(index = ['FA_1', 'FA_5', 'FA_9', 'FA_13', 'FA_17', 'FA_21'])
meani2_TRF_wUF_dm = meani_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
meani2_TRF_wUF_dm = meani2_TRF_wUF_dm.reindex(index = ['FT_1', 'FT_5', 'FT_9', 'FT_13', 'FT_17', 'FT_21'])
meani2_TRF_wUF_dm
# Out:
#                 FA_1      FA_5      FA_9     FA_13     FA_17     FA_21
# group_time
# FT_1        0.197149  0.236894  0.216524  0.227319  0.203511  0.201598
# FT_5        0.136018  0.180518  0.175431  0.240749  0.207321  0.176450
# FT_9        0.105595  0.159200  0.152533  0.249497  0.213600  0.158879
# FT_13       0.301068  0.333490  0.279426  0.373525  0.246517  0.311462
# FT_17       0.320137  0.344361  0.292964  0.306828  0.295501  0.319226
# FT_21       0.203843  0.223601  0.192913  0.235097  0.230123  0.194023

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(meani2_TRF_wUF_dm, cmap='GnBu_r', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.100, vmax=0.350, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances Ad Lib vs TRF (HFD)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/TRF_wUF_ileum_time_mean_heatmap.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### all adlib, compare NCD and HFD

# %%
ddiet5_TRF_wUF_dm = ileum4_TRF_wUF_dm.filter(regex='FA')
ddiet6_TRF_wUF_dm = ddiet5_TRF_wUF_dm.T.filter(regex='NA')
ddiet6_TRF_wUF_dm.head()
# Out:
# group_time     NA_13     NA_13     NA_13     NA_17     NA_17     NA_17  \
# FA_13       0.222866  0.322803  0.296828  0.301754  0.565619  0.263998
# FA_13       0.471203  0.483507  0.462757  0.461647  0.636892  0.397479
# FA_13       0.373447  0.388900  0.364075  0.365226  0.551953  0.302854
# FA_17       0.187638  0.278924  0.254603  0.277725  0.588277  0.246773
# FA_17       0.291392  0.209159  0.275926  0.317825  0.661952  0.261121
#
# group_time     NA_21     NA_21     NA_21      NA_1      NA_1      NA_1  \
# FA_13       0.434191  0.445855  0.291978  0.477433  0.437833  0.370452
# FA_13       0.415196  0.470055  0.441277  0.339326  0.617206  0.534875
# FA_13       0.339964  0.380811  0.346492  0.325757  0.520653  0.440422
# FA_17       0.452314  0.464865  0.272744  0.497318  0.469467  0.373235
# FA_17       0.530491  0.542930  0.315471  0.570422  0.550658  0.423504
#
# group_time      NA_5      NA_5      NA_5      NA_9      NA_9      NA_9
# FA_13       0.543184  0.622351  0.344142  0.522605  0.447945  0.667068
# FA_13       0.555037  0.680036  0.513829  0.597474  0.483609  0.665792
# FA_13       0.518174  0.638573  0.414063  0.515990  0.454896  0.647930
# FA_17       0.565619  0.657914  0.346080  0.523634  0.447431  0.676499
# FA_17       0.617261  0.739033  0.381223  0.587588  0.514375  0.744851

# %%
dmean_TRF_wUF_dm = ddiet6_TRF_wUF_dm.groupby(level=0).mean()
dmean_TRF_wUF_dm = dmean_TRF_wUF_dm.reindex(index = ['FA_1', 'FA_5', 'FA_9', 'FA_13', 'FA_17', 'FA_21'])
dmean2_TRF_wUF_dm = dmean_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
dmean2_TRF_wUF_dm = dmean2_TRF_wUF_dm.reindex(index = ['NA_1', 'NA_5', 'NA_9', 'NA_13', 'NA_17', 'NA_21'])
dmean2_TRF_wUF_dm
# Out:
#                 FA_1      FA_5      FA_9     FA_13     FA_17     FA_21
# group_time
# NA_1        0.454358  0.434257  0.429951  0.451551  0.464340  0.399891
# NA_5        0.519445  0.494080  0.504441  0.536599  0.537492  0.473331
# NA_9        0.522950  0.504883  0.521440  0.555923  0.565068  0.503624
# NA_13       0.289018  0.261638  0.279090  0.376265  0.249814  0.287398
# NA_17       0.387344  0.357285  0.360910  0.427491  0.380286  0.347955
# NA_21       0.389318  0.309110  0.353063  0.396202  0.412134  0.351042

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dmean2_TRF_wUF_dm, cmap='RdPu_r', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.250, vmax=0.575, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances NCD vs HFD (ad libitum)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/TRF_wUF_ileum_diet_mean_heatmap.svg', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### compare NA vs FT

# %%
if5_TRF_wUF_dm = ileum4_TRF_wUF_dm.filter(regex='FT')
if6_TRF_wUF_dm = if5_TRF_wUF_dm.T.filter(regex='NA')
if6_TRF_wUF_dm.head()
# Out:
# group_time     NA_13     NA_13     NA_13     NA_17     NA_17     NA_17  \
# FT_13       0.354885  0.062211  0.194487  0.276812  0.644279  0.217547
# FT_13       0.348013  0.044472  0.191742  0.269960  0.629235  0.200958
# FT_13       0.343306  0.092357  0.189250  0.258076  0.610791  0.173317
# FT_17       0.352311  0.089023  0.195080  0.266486  0.639952  0.213489
# FT_17       0.353242  0.185391  0.200230  0.265809  0.606323  0.157784
#
# group_time     NA_21     NA_21     NA_21      NA_1      NA_1      NA_1  \
# FT_13       0.508888  0.529899  0.247789  0.555429  0.515095  0.422886
# FT_13       0.488501  0.511781  0.231439  0.535197  0.507673  0.406116
# FT_13       0.457848  0.482171  0.211769  0.505515  0.497313  0.385357
# FT_17       0.506495  0.525571  0.244470  0.555131  0.512197  0.418985
# FT_17       0.410194  0.451916  0.214855  0.451370  0.496750  0.380518
#
# group_time      NA_5      NA_5      NA_5      NA_9      NA_9      NA_9
# FT_13       0.673981  0.747685  0.327762  0.604805  0.530536  0.765886
# FT_13       0.657019  0.740691  0.313141  0.596536  0.520027  0.753210
# FT_13       0.632281  0.729244  0.299673  0.586488  0.513596  0.736157
# FT_17       0.669943  0.744513  0.324184  0.602820  0.528501  0.763023
# FT_17       0.601205  0.728261  0.302258  0.585432  0.523197  0.734001

# %%
ifmean_TRF_wUF_dm = if6_TRF_wUF_dm.groupby(level=0).mean()
ifmean_TRF_wUF_dm = ifmean_TRF_wUF_dm.reindex(index = ['FT_1', 'FT_5', 'FT_9', 'FT_13', 'FT_17', 'FT_21'])
ifmean2_TRF_wUF_dm = ifmean_TRF_wUF_dm.T.groupby(level=0).mean().sort_index(axis=0)
ifmean2_TRF_wUF_dm = ifmean2_TRF_wUF_dm.reindex(index = ['NA_1', 'NA_5', 'NA_9', 'NA_13', 'NA_17', 'NA_21'])
ifmean2_TRF_wUF_dm
# Out:
#                 FT_1      FT_5      FT_9     FT_13     FT_17     FT_21
# group_time
# NA_1        0.437971  0.454711  0.447649  0.481176  0.456596  0.437300
# NA_5        0.521726  0.515405  0.501193  0.569053  0.559124  0.515071
# NA_9        0.556725  0.520915  0.496106  0.623027  0.610453  0.539447
# NA_13       0.281865  0.320857  0.320122  0.202302  0.277457  0.340757
# NA_17       0.370613  0.396953  0.393523  0.364553  0.377875  0.396732
# NA_21       0.375954  0.379022  0.375610  0.407787  0.385953  0.381401

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(ifmean2_TRF_wUF_dm, cmap='Oranges_r', linewidths=1, cbar_kws={"shrink": 0.75},
            annot=True, fmt = '.3f', vmin=0.260, vmax=0.625, square=True)
sns.set(font_scale=1.5)
plt.xlabel("")
plt.xticks(ha="center")
plt.ylabel("")
plt.yticks(va="center")
ax.set_title("Mean Weighted Unifrac Distances NCD (ad libitum) vs HFD (TRF)", size=24)
ax.tick_params(labelsize=14)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('../figures/NAvFT_wUF_ileum_diet_mean_heatmap.svg', dpi=300, bbox_inches="tight")
